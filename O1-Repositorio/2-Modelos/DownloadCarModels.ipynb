# %% [markdown]
# # Download

# %% [markdown]
# i have 50modelos.csv
# with this structure...
# Rank,Name
# 1,mg 5
# 2,kia Rio
# 3,toyota Yaris
# 4,toyota Corolla
# 5,mg 4
#
# and it has 50 registers
#
# i have a jupyter script that im attaching.
# i want to download images for each car model
# the folder should have the name format
# <Rank>_<Name> for example, 1_mg_5, 2_kia_Rio, etc.
#
# please adapt the code in order to use it locally and save the on local folders
#
# here is an EXAMPLE ipynb
#
# ##imports
# import math
# import os
# import numpy as np
# import matplotlib.pyplot as plt
# from PIL import Image
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten
# from tensorflow.keras.optimizers import Adam
# ##imports mas interesantes
# from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tqdm import tqdm
# %matplotlib inline
# import shutil
#
# # bing_images_download.py (it exists)
#
# ##selenium stuff
# !pip install selenium
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# import sys
# sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
#
# #TOYOTA
# !python bing_images_download.py -o imagenes1 -i toyotahilux -u "https://www.bing.com/images/search?q=Toyota+Hilux+2023&form=RESTAB&first=1" -l 100 -cd /usr/bin/chromedriver

# %% [markdown]
# # Version 1

# %%
import csv
import os
import subprocess
import urllib.parse

csv_file = 'new-top-50-models.csv'
download_script = 'bing_images_download.py'
#D:\Tesis\chromedriver-win64\chromedriver-win64
chromedriver_path = 'D:\\Tesis\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe'
#chromedriver_path = '/usr/bin/chromedriver'
parent_directory = 'new-images'
num_images = 200

if not os.path.exists(parent_directory):
    os.makedirs(parent_directory)

with open(csv_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        rank = row['Rank'].strip()
        name = row['Name'].strip()
        folder_name = f"{rank}_{name.replace(' ', '_')}"
        squery = f"{name} 2023"
        query_encoded = urllib.parse.quote_plus(query)
        search_url = f"https://www.bing.com/images/search?q={query_encoded}&form=RESTAB&first=1"
        cmd = [
            'python', download_script,
            '-o', parent_directory,
            '-i', folder_name,
            '-u', search_url,
            '-l', str(num_images),
            '-cd', chromedriver_path
        ]
        print("Running command:", " ".join(cmd))
        subprocess.run(cmd)
# Out:
# Running command: python bing_images_download.py -o imagenes -i 1_mg_5 -u https://www.bing.com/images/search?q=mg+5+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 2_kia_Rio -u https://www.bing.com/images/search?q=kia+Rio+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 3_toyota_Yaris -u https://www.bing.com/images/search?q=toyota+Yaris+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 4_toyota_Corolla -u https://www.bing.com/images/search?q=toyota+Corolla+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 5_mg_4 -u https://www.bing.com/images/search?q=mg+4+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 6_kia_Sportage -u https://www.bing.com/images/search?q=kia+Sportage+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 7_hyundai_Accent -u https://www.bing.com/images/search?q=hyundai+Accent+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 8_nissan_Sentra -u https://www.bing.com/images/search?q=nissan+Sentra+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 9_hyundai_Elantra -u https://www.bing.com/images/search?q=hyundai+Elantra+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 10_honda_Civic -u https://www.bing.com/images/search?q=honda+Civic+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 11_hyundai_Tucson -u https://www.bing.com/images/search?q=hyundai+Tucson+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 12_nissan_Versa -u https://www.bing.com/images/search?q=nissan+Versa+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 13_kia_Sorento -u https://www.bing.com/images/search?q=kia+Sorento+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 14_toyota_RAV4 -u https://www.bing.com/images/search?q=toyota+RAV4+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 15_suzuki_Swift -u https://www.bing.com/images/search?q=suzuki+Swift+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 16_hyundai_Santa_Fe -u https://www.bing.com/images/search?q=hyundai+Santa+Fe+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 17_suzuki_Vitara -u https://www.bing.com/images/search?q=suzuki+Vitara+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 18_kia_Seltos -u https://www.bing.com/images/search?q=kia+Seltos+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 19_nissan_Kicks -u https://www.bing.com/images/search?q=nissan+Kicks+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 20_subaru_Forester -u https://www.bing.com/images/search?q=subaru+Forester+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 21_ford_EcoSport -u https://www.bing.com/images/search?q=ford+EcoSport+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 22_jetour_X70 -u https://www.bing.com/images/search?q=jetour+X70+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 23_ford_Explorer -u https://www.bing.com/images/search?q=ford+Explorer+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 24_subaru_Impreza -u https://www.bing.com/images/search?q=subaru+Impreza+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 25_ford_Mustang -u https://www.bing.com/images/search?q=ford+Mustang+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 26_chevrolet_Tracker -u https://www.bing.com/images/search?q=chevrolet+Tracker+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 27_chevrolet_Spark -u https://www.bing.com/images/search?q=chevrolet+Spark+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 28_honda_Pilot -u https://www.bing.com/images/search?q=honda+Pilot+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 29_mitsubishi_Lancer -u https://www.bing.com/images/search?q=mitsubishi+Lancer+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 30_chevrolet_Cruze -u https://www.bing.com/images/search?q=chevrolet+Cruze+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 31_toyota_Tercel -u https://www.bing.com/images/search?q=toyota+Tercel+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 32_mg_3 -u https://www.bing.com/images/search?q=mg+3+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 33_mitsubishi_Montero -u https://www.bing.com/images/search?q=mitsubishi+Montero+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 34_toyota_Land_Cruiser -u https://www.bing.com/images/search?q=toyota+Land+Cruiser+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 35_chevrolet_Camaro -u https://www.bing.com/images/search?q=chevrolet+Camaro+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 36_honda_Accord -u https://www.bing.com/images/search?q=honda+Accord+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 37_toyota_Supra -u https://www.bing.com/images/search?q=toyota+Supra+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 38_mg_6 -u https://www.bing.com/images/search?q=mg+6+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 39_suzuki_Grand_Vitara -u https://www.bing.com/images/search?q=suzuki+Grand+Vitara+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 40_chevrolet_Aveo -u https://www.bing.com/images/search?q=chevrolet+Aveo+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 41_hyundai_Sonata -u https://www.bing.com/images/search?q=hyundai+Sonata+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 42_volkswagen_Golf -u https://www.bing.com/images/search?q=volkswagen+Golf+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 43_mitsubishi_Outlander -u https://www.bing.com/images/search?q=mitsubishi+Outlander+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 44_ford_Escape -u https://www.bing.com/images/search?q=ford+Escape+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 45_ford_Fiesta -u https://www.bing.com/images/search?q=ford+Fiesta+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 46_jac_T8 -u https://www.bing.com/images/search?q=jac+T8+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 47_toyota_Corolla_Cross -u https://www.bing.com/images/search?q=toyota+Corolla+Cross+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 48_volkswagen_Tiguan -u https://www.bing.com/images/search?q=volkswagen+Tiguan+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 49_mitsubishi_Eclipse -u https://www.bing.com/images/search?q=mitsubishi+Eclipse+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o imagenes -i 50_subaru_WRX -u https://www.bing.com/images/search?q=subaru+WRX+2023&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe

# %% [markdown]
# # Version 2

# %%
import csv
import os
import subprocess
import urllib.parse

# %%
def download_car_images(csv_file, parent_directory, num_images):
    download_script = 'bing_images_download.py'
    chromedriver_path = 'D:\\Tesis\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe'

    if not os.path.exists(parent_directory):
        os.makedirs(parent_directory)

    with open(csv_file, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for i, row in enumerate(reader):
            marca = row['Marca'].strip()
            modelo = row['Modelo'].strip()
            #modelo_folder_name = modelo.replace(' ', '_')
            modelo_folder_name = modelo

            marca_path = os.path.join(parent_directory, marca)
            modelo_path = os.path.join(marca_path, modelo_folder_name)

            os.makedirs(modelo_path, exist_ok=True)

            query = f"{modelo}"
            query_encoded = urllib.parse.quote_plus(query)
            search_url = f"https://www.bing.com/images/search?q={query_encoded}&form=RESTAB&first=1"

            cmd = [
                'python', download_script,
                '-o', marca_path,
                '-i', modelo_folder_name,
                '-u', search_url,
                '-l', str(num_images),
                '-cd', chromedriver_path
            ]

            print("Running command:", " ".join(cmd))
            subprocess.run(cmd)

# %%
download_car_images('new-top-50-models.csv', 'bing-model-images', 100)
# Out:
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Hilux -u https://www.bing.com/images/search?q=Toyota+Hilux&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Yaris -u https://www.bing.com/images/search?q=Toyota+Yaris&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Corolla -u https://www.bing.com/images/search?q=Toyota+Corolla&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota RAV4 -u https://www.bing.com/images/search?q=Toyota+RAV4&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Rush -u https://www.bing.com/images/search?q=Toyota+Rush&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Land Cruiser -u https://www.bing.com/images/search?q=Toyota+Land+Cruiser&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Supra -u https://www.bing.com/images/search?q=Toyota+Supra&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Corolla Cross -u https://www.bing.com/images/search?q=Toyota+Corolla+Cross&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Tercel -u https://www.bing.com/images/search?q=Toyota+Tercel&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota 4Runner -u https://www.bing.com/images/search?q=Toyota+4Runner&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Celica -u https://www.bing.com/images/search?q=Toyota+Celica&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota FJ Cruiser -u https://www.bing.com/images/search?q=Toyota+FJ+Cruiser&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota C-HR -u https://www.bing.com/images/search?q=Toyota+C-HR&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Camry -u https://www.bing.com/images/search?q=Toyota+Camry&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\TOYOTA -i Toyota Prius -u https://www.bing.com/images/search?q=Toyota+Prius&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai Accent -u https://www.bing.com/images/search?q=Hyundai+Accent&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai Elantra -u https://www.bing.com/images/search?q=Hyundai+Elantra&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai Tucson -u https://www.bing.com/images/search?q=Hyundai+Tucson&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai Santa Fe -u https://www.bing.com/images/search?q=Hyundai+Santa+Fe&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai Creta -u https://www.bing.com/images/search?q=Hyundai+Creta&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai i20 -u https://www.bing.com/images/search?q=Hyundai+i20&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai Sonata -u https://www.bing.com/images/search?q=Hyundai+Sonata&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\HYUNDAI -i Hyundai Veloster -u https://www.bing.com/images/search?q=Hyundai+Veloster&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\KIA -i Kia Rio -u https://www.bing.com/images/search?q=Kia+Rio&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\KIA -i Kia Sportage -u https://www.bing.com/images/search?q=Kia+Sportage&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\KIA -i Kia Sorento -u https://www.bing.com/images/search?q=Kia+Sorento&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\KIA -i Kia Seltos -u https://www.bing.com/images/search?q=Kia+Seltos&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\KIA -i Kia Soul -u https://www.bing.com/images/search?q=Kia+Soul&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\KIA -i Kia Niro -u https://www.bing.com/images/search?q=Kia+Niro&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHEVROLET -i Chevrolet Camaro -u https://www.bing.com/images/search?q=Chevrolet+Camaro&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHEVROLET -i Chevrolet Onix -u https://www.bing.com/images/search?q=Chevrolet+Onix&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHEVROLET -i Chevrolet Spark -u https://www.bing.com/images/search?q=Chevrolet+Spark&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHEVROLET -i Chevrolet Cruze -u https://www.bing.com/images/search?q=Chevrolet+Cruze&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHEVROLET -i Chevrolet Tracker -u https://www.bing.com/images/search?q=Chevrolet+Tracker&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHANGAN -i Changan CS35 -u https://www.bing.com/images/search?q=Changan+CS35&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHANGAN -i Changan CS55 -u https://www.bing.com/images/search?q=Changan+CS55&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\CHANGAN -i Changan New Van -u https://www.bing.com/images/search?q=Changan+New+Van&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\NISSAN -i Nissan Sentra -u https://www.bing.com/images/search?q=Nissan+Sentra&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\NISSAN -i Nissan Versa -u https://www.bing.com/images/search?q=Nissan+Versa&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\NISSAN -i Nissan Kicks -u https://www.bing.com/images/search?q=Nissan+Kicks&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\SUZUKI -i Suzuki Vitara -u https://www.bing.com/images/search?q=Suzuki+Vitara&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\SUZUKI -i Suzuki Swift -u https://www.bing.com/images/search?q=Suzuki+Swift&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\SUZUKI -i Suzuki Jimny -u https://www.bing.com/images/search?q=Suzuki+Jimny&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\DFSK -i Glory 580 -u https://www.bing.com/images/search?q=Glory+580&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\DFSK -i Glory 500 -u https://www.bing.com/images/search?q=Glory+500&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\DFSK -i Glory 330 -u https://www.bing.com/images/search?q=Glory+330&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\JAC -i JAC T8 -u https://www.bing.com/images/search?q=JAC+T8&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\JAC -i JAC JS4 -u https://www.bing.com/images/search?q=JAC+JS4&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\VOLKSWAGEN -i Volkswagen Golf -u https://www.bing.com/images/search?q=Volkswagen+Golf&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
# Running command: python bing_images_download.py -o bing-model-images\VOLKSWAGEN -i Volkswagen Tiguan -u https://www.bing.com/images/search?q=Volkswagen+Tiguan&form=RESTAB&first=1 -l 100 -cd D:\Tesis\chromedriver-win64\chromedriver-win64\chromedriver.exe
